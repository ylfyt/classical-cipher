# %%
import copy

cipher_b2 = "..."

# %%
from collections import Counter
import string
import copy

alphabet = list(string.ascii_uppercase)
topTenCharacter = ['E', 'T', 'A', 'O', 'I', 'N', 'S', 'H', 'R', 'D', 'L', 'U']
frequencyTable = Counter(cipher_b2).most_common(10)

ngrams = lambda a, n: zip(*[a[i:] for i in range(n)])


print("Most used char: E, T, A, O, I, N, S, H, R, D, L, U \n")
print("Most used bigrams: TH, HE, IN, EN, NT, RE, ER, AN, TI, dan ES \n")

print("TRIGRAMS")
print(Counter(ngrams(cipher_b2, 3)).most_common(10))
print("Most used trigrams: THE, AND, THA, ENT, ING, ION, TIO, FOR, NDE, dan HAS \n")

print("4GRAMS")
print(Counter(ngrams(cipher_b2, 4)).most_common(5))
print()

print("5GRAMS")
print(Counter(ngrams(cipher_b2, 5)).most_common(5))
print()

print("8GRAMS")
print(Counter(ngrams(cipher_b2, 8)).most_common(5))
print()

def factor_tree(x):
    arr = []
    for i in range(1, x + 1):
        if x % i == 0:
            arr.append(i)
    return arr

def intersection(lst1, lst2):
    lst3 = [value for value in lst1 if value in lst2]
    return lst3

threeGramsText = copy.deepcopy(cipher_b2).replace("HSS", " hss ")
fiveGramsText = copy.deepcopy(cipher_b2).replace("WZMCY", " wzmcy ")
eightGramsText = copy.deepcopy(cipher_b2).replace("ECHYYEGK", " echyyegk ")
print(threeGramsText)
# print(fiveGramsText)
# print(eightGramsText)

threeGramsFirstDistance = len("ssLMEQWZMCYCLJNOAZSPLHNGFXESIh")
threeGramsSecondDistance = len("...")
threeGramsThirdDistance = len("ssLMEGAUJh")
threeGramsFourthDistance = len("")
threeGramsFifthDistance = len("ssKKRVCKRQPCLQNQKYMFTGRYAHPNIFPWYYYWKLSZVZUPREXUYHECHYYEGKMGDOOBUIOGMRLHOKRADKRh")
threeGramsSixthDistance = len("ssXCJEOGJOCAKPAEIKHHZPGUUSSKRHQWYFVRCZSh")
threeGramsSeventhDistance = len("ssXGIINZSUPHLGFLPUIOEHUZNKAZWOMWMYAHXKEIEWLSYJEYLPFHNCVWOAVDCWYCQXDGXh")
threeGramsEightDistance = len("ssLGFLYGRHLZQYCTWXIBEZERUIBOWVTGZFRMJIEFYOZGBRKLEDCWTARWOCLCHOYAHVOKHTZFBGBPWZMBRHNCEYHKWCQHNCXMJMHCXOYYGLWTOMZILMELWBMBRFKJREOKHVPFLPBQPNIQFFYCGLAVVWYQKQFAWYQOCFERBFWNSKPJKPGLAXIWDCTCCVKSMGPHNYGLWYFSPBGEEIAJYDZBZFRCONSIWRTMGXARPOYMULRXDGXh")
threeGramsNinthDistance = len("...")
threeGramsTenthDistance = len("ssVSQHHKXICBKBVRPUEZLYKRUEPOWBZKIYYPAJXCMORYXIPNIBEVKGFPWTHKSSXCFEIUWWCGNCYXAXMGNORJRHOGQCDWXGFPWTHHSOZQGLANMGECXWBJPUFOWOQCGLWZWGZITGDYAXMUSHODLSQBMGTHZMOEHGOSJCAANRBKIZEVKABSHGXAZGVFRVAUJh")

fiveGramsFirstDistance = len("zmcyCLJNOAZSPLHNGFXESIHSSXCVWOUQSTBLMEQw")
fiveGramsSecondDistance = len("...")
fiveGramsThirdDistance = len("...")

eightGramsFirstDistance = len("")

eightGramsSecondDistance = len("...")


print("Kriptogram: HSS")
print("Jarak kriptogram 1 ke 2: ", threeGramsFirstDistance)
print("Jarak kriptogram 2 ke 3: ", threeGramsSecondDistance)
print("Jarak kriptogram 3 ke 4: ", threeGramsThirdDistance)
print("Jarak kriptogram 4 ke 5: ", threeGramsFourthDistance)
print("Jarak kriptogram 5 ke 6: ", threeGramsFifthDistance)
print("Jarak kriptogram 6 ke 7: ", threeGramsSixthDistance)
print("Jarak kriptogram 7 ke 8: ", threeGramsSeventhDistance)
print("Jarak kriptogram 8 ke 9: ", threeGramsEightDistance)
print("Jarak kriptogram 9 ke 10: ", threeGramsNinthDistance)
print("Jarak kriptogram 10 ke 11: ", threeGramsTenthDistance)


print("Intersection dari faktor pembagi: [1, 2, 5, 10]")

print("\n======================================================\n")


print("Kriptogram: WZMCY")
print("Jarak kriptogram 1 ke 2: ", fiveGramsFirstDistance)
print("Jarak kriptogram 2 ke 3: ", fiveGramsSecondDistance)
print("Jarak kriptogram 3 ke 4: ", fiveGramsThirdDistance)

intersection1 = intersection(factor_tree(fiveGramsFirstDistance), factor_tree(fiveGramsSecondDistance))
print("Intersection dari faktor pembagi: ", intersection(intersection1, factor_tree(fiveGramsThirdDistance)))

print("\n======================================================\n")

print("Kriptogram: ECHYYEGK")
print("Jarak kriptogram 1 ke 2: ", eightGramsFirstDistance)
print("Jarak kriptogram 2 ke 3: ", eightGramsSecondDistance)

print("Intersection dari faktor pembagi: ", intersection(factor_tree(eightGramsFirstDistance), factor_tree(eightGramsSecondDistance)))
# Out:
# Most used char: E, T, A, O, I, N, S, H, R, D, L, U
#
# Most used bigrams: TH, HE, IN, EN, NT, RE, ER, AN, TI, dan ES
#
# TRIGRAMS
# [(('H', 'S', 'S'), 11), (('P', 'N', 'I'), 11), (('X', 'V', 'P'), 8), (('H', 'N', 'C'), 7), (('G', 'L', 'A'), 6), (('L', 'M', 'E'), 5), (('W', 'Z', 'M'), 5), (('E', 'V', 'K'), 5), (('Z', 'F', 'R'), 5), (('Y', 'A', 'H'), 5)]
# Most used trigrams: THE, AND, THA, ENT, ING, ION, TIO, FOR, NDE, dan HAS
#
# 4GRAMS
# [(('W', 'Z', 'M', 'C'), 4), (('Z', 'M', 'C', 'Y'), 4), (('R', 'B', 'F', 'W'), 4), (('E', 'C', 'H', 'Y'), 3), (('C', 'H', 'Y', 'Y'), 3)]
#
# 5GRAMS
# [(('W', 'Z', 'M', 'C', 'Y'), 4), (('E', 'C', 'H', 'Y', 'Y'), 3), (('C', 'H', 'Y', 'Y', 'E'), 3), (('H', 'Y', 'Y', 'E', 'G'), 3), (('Y', 'Y', 'E', 'G', 'K'), 3)]
#
# 8GRAMS
# ...

# %%
print("Akan ditebak panjang kunci berdasarkan irisan dari faktor pembagi yaitu 10")
print("Most used char: E, T, A, O, I, N, S, H, R, D, L, U \n")

print("TRIGRAMS")
print(Counter(ngrams(cipher_b2, 3)).most_common(15))
print("Most used trigrams: THE, AND, THA, ENT, ING, ION, TIO, FOR, NDE, dan HAS \n")
cipherText = ""

for i in range(1, len(cipher_b2)+1) :
    if i % 100 == 0 and i != 0:
        char = cipher_b2[i-1] + " \n"
    elif i == 0:
        char = cipher_b2[i-1]
    elif i % 10 == 0:
        char = cipher_b2[i-1] + " "
    else:
        char = cipher_b2[i-1]
    cipherText = cipherText + char

print(cipherText.replace("HSS", "   hss"))


groupTextDict = {
    "row1" : "",
    "row2" : "",
    "row3" : "",
    "row4" : "",
    "row5" : "",
    "row6" : "",
    "row7" : "",
    "row8" : "",
    "row9" : "",
    "row10" : "",
}

for i in range(0, len(cipher_b2)):
    rowNumber = str((i+1) % 10)
    if int(rowNumber) == 0:
        rowNumber = str(10)
    groupTextDict["row"+rowNumber] += cipher_b2[i]


for row in groupTextDict:
    print(row, ": ", Counter(groupTextDict[row]).most_common(1))


# groupTextDict["row"+str(1)] += "asd"
# print(groupTextDict["row"+str(1)])
# Out:
# Akan ditebak panjang kunci berdasarkan irisan dari faktor pembagi yaitu 10
# Most used char: E, T, A, O, I, N, S, H, R, D, L, U
#
# TRIGRAMS
# [(('H', 'S', 'S'), 11), (('P', 'N', 'I'), 11), (('X', 'V', 'P'), 8), (('H', 'N', 'C'), 7), (('G', 'L', 'A'), 6), (('L', 'M', 'E'), 5), (('W', 'Z', 'M'), 5), (('E', 'V', 'K'), 5), (('Z', 'F', 'R'), 5), (('Y', 'A', 'H'), 5), (('H', 'Y', 'Y'), 4), (('Z', 'M', 'C'), 4), (('M', 'C', 'Y'), 4), (('S', 'S', 'X'), 4), (('K', 'T', 'R'), 4)]
# Most used trigrams: THE, AND, THA, ENT, ING, ION, TIO, FOR, NDE, dan HAS
#
# FSIKTSZDRC ZEUGPFPOJW XRKCXVPVOQ GSNESTECHY YEGKPCNOZC QMJTSFEVYS ZEPXEDCCBG AGAHYHQCXR USOKSTJCAU USZURCEYTM
# JXDKWHZFEZ RLETH   hssLM EQWZMCYCLJ NOAZSPLHNG FXESI   hssXC VWOUQSTBLM EQWZMCYHNY GAERPPPROQ PYOYIRNIXG BYOGWKSOZP
# REZOXRZKTR BFWREYPWYM AIKLXVPZGP TIOZPOVSYG AWKAXVPOYR NWEGEBOWYY ISHIEBTQRY XIETXVPAOB QPAZLSCSOQ NREYPOYRIY
# ...
