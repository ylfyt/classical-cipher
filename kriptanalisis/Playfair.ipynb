# %%
cipher_b3 = "..."

# %%
from collections import Counter
ngrams = lambda a, n: zip(*[a[i:] for i in range(n)])

print("BIGRAMS")
print(Counter(ngrams(cipher_b3, 2)).most_common(15))
print("Most used bigrams: TH, HE, IN, EN, NT, RE, ER, AN, TI, dan ES \n")

print("QUADRIGRAMS")
print(Counter(ngrams(cipher_b3, 4)).most_common(30))

# belum selesai
# Out:
# BIGRAMS
# [(('B', 'L'), 296), (('S', 'H'), 268), (('U', 'G'), 142), (('F', 'T'), 142), (('K', 'B'), 125), (('F', 'B'), 122), (('H', 'Z'), 117), (('C', 'H'), 117), (('G', 'R'), 116), (('L', 'A'), 111), (('E', 'M'), 105), (('L', 'R'), 102), (('Z', 'D'), 101), (('L', 'U'), 99), (('B', 'K'), 95)]
# Most used bigrams: TH, HE, IN, EN, NT, RE, ER, AN, TI, dan ES
#
# QUADRIGRAMS
# [(('Z', 'D', 'L', 'R'), 45), (('L', 'U', 'S', 'H'), 35), (('B', 'U', 'S', 'H'), 29), (('P', 'W', 'P', 'C'), 28), (('Q', 'B', 'W', 'U'), 27), (('H', 'D', 'E', 'M'), 25), (('P', 'C', 'G', 'R'), 23), (('R', 'V', 'B', 'L'), 23), (('F', 'T', 'L', 'U'), 22), (('D', 'L', 'R', 'A'), 22), (('B', 'L', 'K', 'B'), 22), (('U', 'Q', 'X', 'Y'), 22), (('Q', 'X', 'Y', 'Z'), 22), (('X', 'Y', 'Z', 'D'), 22), (('Y', 'Z', 'D', 'L'), 22), (('C', 'G', 'R', 'I'), 22), (('G', 'R', 'I', 'Y'), 22), (('R', 'I', 'Y', 'H'), 22), (('I', 'Y', 'H', 'D'), 22), (('Y', 'H', 'D', 'E'), 22), (('D', 'E', 'M', 'M'), 22), (('G', 'R', 'B', 'L'), 22), (('B', 'W', 'U', 'Z'), 21), (('M', 'E', 'G', 'I'), 21), (('B', 'L', 'F', 'Z'), 21), (('B', 'L', 'C', 'Z'), 20), (('H', 'P', 'W', 'P'), 20), (('W', 'U', 'Z', 'D'), 20), (('U', 'Z', 'D', 'L'), 20), (('B', 'L', 'L', 'A'), 19)]
