# %%
cipher_b1 = "..."

# %%
from collections import Counter
import string

alphabet = list(string.ascii_uppercase)
topTenCharacter = ['E', 'T', 'A', 'O', 'I', 'N', 'S', 'H', 'R', 'D', 'L', 'U']
frequencyTable = Counter(cipher_b1).most_common(10)

ngrams = lambda a, n: zip(*[a[i:] for i in range(n)])

print("FREQUENCY TABLE")
print(frequencyTable)
print("Most used char: E, T, A, O, I, N, S, H, R, D, L, U \n")

print("BIGRAMS")
print(Counter(ngrams(cipher_b1, 2)).most_common(10))
print("Most used bigrams: TH, HE, IN, EN, NT, RE, ER, AN, TI, dan ES \n")

print("TRIGRAMS")
print(Counter(ngrams(cipher_b1, 3)).most_common(10))
print("Most used trigrams: THE, AND, THA, ENT, ING, ION, TIO, FOR, NDE, dan HAS \n")

# print("4GRAMS")
# print(Counter(ngrams(cipher_b1, 4)).most_common(5))
# print()
#
# print("5GRAMS")
# print(Counter(ngrams(cipher_b1, 5)).most_common(5))
# print()

cipherText = ""
i = 0
for i in range(0, len(cipher_b1)) :
    if i % 100 == 0 and i != 0:
        char = cipher_b1[i] + " \n"
    elif i % 5 == 0 and i != 0:
        char = cipher_b1[i] + " "
    else:
        char = cipher_b1[i]
    cipherText = cipherText + char

# W disubstitusi E sesuai dengan urutan tabel frekuensi
cipherText = cipherText.replace("W", "e")
# C disubstitusi T sesuai dengan urutan tabel frenkuensi
cipherText = cipherText.replace("C", "t")
# Z disubstitusi H karena CZW merupakan trigram paling banyak digunakan dan W & C sudah ditebak
cipherText = cipherText.replace("Z", "h")

# N -> I dan J -> N dengan membandingkan tabel bigrams
cipherText = cipherText.replace("N", "i")
cipherText = cipherText.replace("J", "n")

# P -> G berdasarkan tabel trigram, (NJP) -> (ING) dengan N -> I dan J -> N
cipherText = cipherText.replace("P", "g")

# F -> A dan Y -> D berdasarkan tabel trigram, (FJY) -> (AND) dengan J -> N
cipherText = cipherText.replace("F", "a")
cipherText = cipherText.replace("Y", "d")

# K -> R berdasarkan tabel bigram, (WK) -> (ER) dengan W -> E
cipherText = cipherText.replace("K", "r")

# X -> O berdasarkan frequency table
cipherText = cipherText.replace("X", "o")

# L -> S berdasarkan frequency table dan ada substring theorieL sehingga kemungkinan L -> S
cipherText = cipherText.replace("L", "s")

# 40 karakter pertama: therea reUar ioHst heori esast oQher ethet erEUi
# -> there are (Uar ioHs) theories as to Qher ethet erEUi
# (Uar ioHs) dapat ditebak various sehingga U -> V dan H -> U
cipherText = cipherText.replace("U", "v")
cipherText = cipherText.replace("H", "u")

# sekitar karakter 500 terdapat kalimat: d uring thise arVRG eriod itQas ntVon gunti VAont
# -> during this (earVR) (Geriod) it (Qasnt) (Vong) (untiV) Aont
# (earVR): V -> L dan R -> Y
# (Geriod): G -> P
# (Qasnt): Q -> W
# (untiV): V -> L
cipherText = cipherText.replace("V", "l")
cipherText = cipherText.replace("R", "y")
cipherText = cipherText.replace("G", "p")
cipherText = cipherText.replace("Q", "w")

# ada kata (reAog nised) yang mirip dengan recognised sehingga A -> C
cipherText = cipherText.replace("A", "c")

# ada kata (set tleEe nt) yang mirip dengan settlement sehingga E -> M
cipherText = cipherText.replace("E", "m")

# pada awal text ada kalimat therea revar ioust heori esast owher ethet ermvi Sing
# -> there are various theories as to where the term (viSing)
# (viSing) mirip dengan viking sehingga S -> K
cipherText = cipherText.replace("S", "k")

# Pada akhir teks: r ecogn isedB orcei nthew orldt hough their Oruta lityO raver yands treng thwou ldlon gOere
# memOe redOy those whoha donce Beltt hesha rpedg eoBth eirOa ttlea Ie
# -> recognised (Borce) in the world though their (Orutality) (Oravery) and strength would long (Oe)
# (rememOered) (Oy) those who had once (Belt) the sharped (geoB) their (Oattle) (aIe)
# dapat ditebak B -> F, O -> B, I -> X
cipherText = cipherText.replace("B", "f")
cipherText = cipherText.replace("O", "b")
cipherText = cipherText.replace("I", "x")

# ada kalimat: forei gners orTui tesui tably
# -> foreigners or (Tuite) suitably
# bisa ditebak T -> Q
cipherText = cipherText.replace("T", "q")

# ada kalimat: conq uesto fMeru salem
# -> conquest of (Merusalem)
# bisa ditebak M -> Y
cipherText = cipherText.replace("M", "y")

# character terakhir adalah D -> Z
cipherText = cipherText.replace("D", "z")

print(cipherText)
# Out:
# FREQUENCY TABLE
# [('W', 539), ('C', 376), ('J', 323), ('F', 320), ('N', 318), ('X', 298), ('K', 277), ('L', 269), ('Z', 211), ('V', 178)]
# Most used char: E, T, A, O, I, N, S, H, R, D, L, U
#
# BIGRAMS
# [(('C', 'Z'), 144), (('Z', 'W'), 113), (('N', 'J'), 91), (('W', 'K'), 86), (('F', 'J'), 78), (('K', 'W'), 70), (('W', 'J'), 67), (('J', 'P'), 64), (('X', 'K'), 55), (('L', 'C'), 54)]
# Most used bigrams: TH, HE, IN, EN, NT, RE, ER, AN, TI, dan ES
#
# TRIGRAMS
# [(('C', 'Z', 'W'), 102), (('N', 'J', 'P'), 51), (('F', 'J', 'Y'), 36), (('W', 'K', 'W'), 26), (('S', 'N', 'J'), 23), (('W', 'J', 'C'), 23), (('Z', 'W', 'K'), 22), (('U', 'N', 'S'), 21), (('B', 'X', 'K'), 19), (('N', 'S', 'N'), 17)]
# Most used trigrams: THE, AND, THA, ENT, ING, ION, TIO, FOR, NDE, dan HAS
#
# []
# therea revar ioust heori esast owher ethet ermvi kingo rigin atedo neloo kstot hefem inine prefi xvikm eanin ginle torba
# ywhil eothe rscla imthe histo ricno rwegi anset tleme ntofv ikeni swher ethen amede rives hence vikin gswer etheo rigin
# aldwe llers ofvik enalt ernat ively recog nised etymo logis tssuc hasan atoly liber manpo intto theol dnors eword vikam
# eanin gseam ileth espac eleft betwe entwo rowin gboat sinco nvoyw hileo thers refer tothe thcen turya nglos axonp oemwi
# dsith which refer stosc andin avian pirat esasw icing srega rdles sgive nthes candi navia nsdom inanc eofth esead uring
# thise arlyp eriod itwas ntlon gunti lcont rasti ngnam eswer ebein goffe redup byvar iouso therc ultur esacr ossth eplan
# etthe arabs slavs andby zanti nesfo rexam plekn ewoft heser aider sasru sorrh osrel ating torow ingwh ileth egerm ansla
# belle dthem asasc omann iashm enall uding tothe irash woodb oatso thern ation ssuch asthe engli shand celts settl edmer
# elyon danes heath ensor pagan swhil stthe irish refer redto thema sdubg ailan dfinn gaild arkan dfair forei gners orqui
# tesui tably north mengi venth ecomm oncul tural pract iceof torme nting coast alset tleme ntsan dmona steri esitw asntl
# ongun tilth eviki ngsfe arsom erepu tatio nspre adtoa lmost allco rners ofeur opean dmeso potam iathe reise venev idenc
# ethat thevi kings reach edbag hdadt hecen treof theis lamic empir eatth etime thevi kinga geasc ommon lyref erred tolas
# tedfr omthe early stoth enorm ancon quest ofeng landi nthro ughou tthis perio dthev iking sused theno rther nandb altic
# seast oterr orise neigh bouri ngkin gdoms exten dingt heiri nflue nceth rough comba tandc ultur eunti leven tuall yviki
# ngsco uldno longe rbeme relyd escri bedas coast alrai dersc onsid erthe facts twovi kingk ingss weynf orkbe ardan dcnut
# thegr eatwo uldas cendt heeng lisht hrone leife rikso nanea rlyic eland erwou ldset tlesh ortiv edcol onies innor thame
# ricas candi navia nswou ldeve nserv easme rcena riesf orthe byzan tinee mpire insho rtthe sewer enome repir atesb utthe
# foref ather sofap atchw orkqu iltcu lture themo tivat ionsf orsuc hexpa nsion aresu byect todeb atefo rmode rnhis toria
# nstho ughth erear eclea rince ntive sasto whyth epopu latio nofsc andin aviam ighth aveac tedin thewa ythat theyd iddur
# ingth isyea rperi odone relat ively appar entre asoni sasca rcity ofres ource sthus forci ngthe vikin gstol ookfu rther
# afiel deven robbi ngand killi ngcla sseso fpeop leble ssedw itham orebo untif ulhom eland anoth erpos sible stimu lusis
# theru leofc harle magne andth ereli gious perse cutio nthat wenth andin handw ithit withc hrist ianin fluen cesee pinge
# verfu rther intod enmar kswed enand norwa yitma keslo gical sense thatt hevik ingsw erelo oking topro tectt heirp aganb
# elief syste mresi styud eochr istia nvalu esand event akere venge forth osese ttlem entsa lread ylost toamo nothe istic
# devot ionth isisn otspe culat ionth eintr oduct ionof chris tiani tywou ldcom etodi viden orway foral mosth alfac entur
# ycaus ingun toldb loods hedan dcult uralt ransf ormat ionit shoul dalso benot edtha tduri ngthe vikin gages candi navia
# sclos estne ighbo urswe reexp erien cingv aryin gleve lsofi nnert urmoi lthus grant ingth eviki ngsan advan tagew henex
# ploit ingth esela ndsfo rweal thsla vesor terri toryt hesea route sused bythe vikin gswer ealmo stent irely freeo foppo
# sitio nleav ingth eraid ersun imped edast heytr avell edfro moned estin ation ofplu ndert othen extth isbre akdow ninwh
# athad onceb eenap rofit ablen etwor koftr adero utesf oreur opean kingd omsca nbehe ralde dback asfar asthe colla pseof
# thero manem pirei nthet hcent uryan dlate rtoth erapi dthce ntury expan siono fisla micph iloso phyth eendo fthev iking
# ageca nbepi nnedd ownto anumb eroff actor sfirs tofal lthef allou tthat occur redfo llowi ngthe chris tiani satio nofsc
# andin aviaw ouldh aveun tolde ffect sonth eregi onsdo mesti candf oreig npoli cybyt hethc entur ydenm arkno rwaya ndswe
# denwe reeff ectiv elyco ntrol ledby dioce sesle gitim isedb ythec athol icchu rchan dhadf irmly estab lishe dthem selve
# sasse parat eking domst hisme antan enorm ouscu ltura lshif tinth eprio ritie sofsc andin avias leade rship intha tsens
# ethev iking swere notde feate dbuta rguab lymad etobe havei naman nerth atfit theci vilit yofth eirqu ickly trans formi
# nghom eland sfore xampl ethem ediev alchu rchma deitf orbid dento takef ellow chris tians assla vesgi venth efact thats
# lavet radin gwast henum beron esour ceofp rofit forth eviki ngsth isrem oveda great dealo fthee conom icinc entiv etotr
# avela ndrai dover seast henew leade rship alsoc hoset orefo custh eirmi litar yatte ntion fromt hekin gdoms ofthe westa
# ndins teadp artak einsu chcam paign sasth ebalt icwar sandt heatt empte dconq uesto fyeru salem fromh ereon outit seeme
# dthev iking swere nolon gerar ecogn isedf orcei nthew orldt hough their bruta lityb raver yands treng thwou ldlon gbere
# membe redby those whoha donce feltt hesha rpedg eofth eirba ttlea xe
